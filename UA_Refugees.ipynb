# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from scipy import interpolate
import matplotlib.pyplot as plt
import numpy as np
from bokeh.models import ColumnDataSource, Label, LabelSet, Range1d

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# coordinates (x,y) of all locations

RU = (17,13) #Russia
PL = (13,9) #Poland
DE = (10,9) #Germany
CZ = (8,8) #Czech Republic
IT = (10,5) #Italy
TR = (18,3) #Turkey
ES = (4,4) #Spain
UK = (6,10) #United Kingdom
FR = (7,7) #France
SK = (13,8) #Slovakia
MD = (17,7) #Moldova
RO = (16,6) #Romania
AT = (8,7) #Austria
BG = (16,4) #Bulgaria
NL = (8,10) #Netherlands
CH = (9,6) #Switzerland
LT = (14,11) #Lithuania
BE = (7,9) #Belgium
EE = (14,13) #Estonia
PT = (2,4) #Portugal
IE = (4,11) #Ireland
SE = (12,17) #Sweden
LV = (14,12) #Latvia
FI = (14,16) #Finland
DK = (12,9) #Denmark
HU = (13,6) #Hungary
GA = (20,7) #Georgia
ME = (13,4) #Montenegro
NO = (10,15) #Norway
HR = (12,5) #Croatia
GR = (14,2) #Greece
RS = (14,5) #Serbia and Kosovo
CY = (19,1) #Cyprus
BY = (15,10) #Belarus

UA = (17,8) #Ukraine

# %%
# dictionary of country name and its location in coordinates (x,y)
dict_country_to_location = {'Ukraine': [17,9],
                            'Russia': [18,14],
                            'Poland': [12,10],
                            'Germany': [9,10],
                            'Czech Republic': [9,7],
                            'Italy': [9,5],
                            'Turkey': [18,3],
                            'Spain': [2,4],
                            'United Kingdom': [5,11],
                            'France': [5,7],
                            'Slovakia': [13,8],
                            'Moldova': [17,7],
                            'Romania': [15,7],
                            'Austria': [8,7],
                            'Bulgaria': [15,5],
                            'Netherlands': [7,10],
                            'Switzerland': [9,6],
                            'Lithuania': [14,11],
                            'Belgium': [7,9],
                            'Estonia': [14,13],
                            'Portugal': [2,4],
                            'Ireland': [4,11],
                            'Sweden': [12,17],
                            'Latvia': [14,12],
                            'Finland': [14,16],
                            'Denmark': [12,9],
                            'Hungary': [13,6],
                            'Georgia': [20,7],
                            'Montenegro': [13,4],
                            'Norway': [10,15],
                            'Croatia': [12,5],
                            'Greece': [14,2],
                            'Serbia': [14,5],
                            'Cyprus': [19,1],
                            'Belarus': [15,11]}
list(dict_country_to_location.values())
# Out:
# [[17, 9],
#  [18, 14],
#  [12, 10],
#  [9, 10],
#  [9, 7],
#  [9, 5],
#  [18, 3],
#  [2, 4],
#  [5, 11],
#  [5, 7],
#  [13, 8],
#  [17, 7],
#  [15, 7],
#  [8, 7],
#  [15, 5],
#  [7, 10],
#  [9, 6],
#  [14, 11],
#  [7, 9],
#  [14, 13],
#  [2, 4],
#  [4, 11],
#  [12, 17],
#  [14, 12],
#  [14, 16],
#  [12, 9],
#  [13, 6],
#  [20, 7],
#  [13, 4],
#  [10, 15],
#  [12, 5],
#  [14, 2],
#  [14, 5],
#  [19, 1],
#  [15, 11]]

# %%
# weight, meaning number of refugees from Ukraine to that country

RU_weight = 2772010
PL_weight = 1409139
DE_weight = 997895
CZ_weight = 433488
IT_weight = 170646
TR_weight = 145000
ES_weight = 144668
UK_weight = 120600
FR_weight = 105000
SK_weight = 90612
MD_weight = 90525
RO_weight = 86178
AT_weight = 82446
BG_weight = 77114
NL_weight = 76600
CH_weight = 64053
LT_weight = 63279
BE_weight = 56013
EE_weight = 51501
PT_weight = 49718
IE_weight = 46481
SE_weight = 45552
LV_weight = 36912
FI_weight = 36652
DK_weight = 35193
HU_weight = 30000
GA_weight = 26376
ME_weight = 24482
NO_weight = 27844
HR_weight = 21877
GR_weight = 18745
RS_weight = 18596
CY_weight = 13852
BY_weight = 12505

# %%
RU_x = [17,18]
RU_y = [9,14]
PL_x = [17,12]
PL_y = [9,10]
DE_x = [17,9]
DE_y = [9,10]
CZ_x = [17,9]
CZ_y = [9,7]
IT_x = [17,9]
IT_y = [9,5]
TR_x = [17,18]
TR_y = [9,3]
ES_x = [17,2]
ES_y = [9,4]
UK_x = [17,5]
UK_y = [9,11]
FR_x = [17,5]
FR_y = [9,7]
SK_x = [17,13]
SK_y = [9,8]
MD_x = [17,17]
MD_y = [9,7]
RO_x = [17,15]
RO_y = [9,7]
AT_x = [17,8]
AT_y = [9,7]
BG_x = [17,15]
BG_y = [9,5]
NL_x = [17,7]
NL_y = [9,10]

#CH = (9,6) #Switzerland
#LT = (14,11) #Lithuania
#BE = (7,9) #Belgium
#EE = (14,13) #Estonia
#PT = (2,4) #Portugal
#IE = (4,11) #Ireland
#SE = (12,17) #Sweden
#LV = (14,12) #Latvia
#FI = (14,16) #Finland
#DK = (12,9) #Denmark
#HU = (13,6) #Hungary
#GA = (20,7) #Georgia
#ME = (13,4) #Montenegro
#NO = (10,15) #Norway
#HR = (12,5) #Croatia
#GR = (14,2) #Greece
GR_x = [17,14]
GR_y = [9,2]

#RS = (14,5) #Serbia and Kosovo
#CY = (19,1) #Cyprus
#BY = (15,10) #Belarus
BY_x = [17,15]
BY_y = [9,11]

#UA = (17,8) #Ukraine

# %%
UA_RU_x = [17,18]
UA_RU_y = [9,14]

UA_RO_BG_x = [17,15,16]
UA_RO_BG_y = [9,7,4]

UA_PL_x = [17,13]
UA_PL_y = [9,9]

UA_PL_DE_x = [17,13,9]
UA_PL_DE_y = [9,9,10]

UA_PL_DE_FR_x = [17,13,9,5]
UA_PL_DE_FR_y = [9,9,10,7]

UA_BY_RU_x = [17,15,18]
UA_BY_RU_y = [9,11,14]

UA_TR_GR_IT_FR_x = [17,18,14,9,5]
UA_TR_GR_IT_FR_y = [9,3,2,5,7]

# %%
p = figure(plot_width = 800, plot_height = 500, title = "Points")

# %%
e = []
names = dict_country_to_location.keys()
for location in list(names):
    e.append(dict_country_to_location[location])
e = np.array(e)
x_locations = e.T[0]
y_locations = e.T[1]
print(x_locations, y_locations)
# Out:
# [17 18 12  9  9  9 18  2  5  5 13 17 15  8 15  7  9 14  7 14  2  4 12 14
#  14 12 13 20 13 10 12 14 14 19 15] [ 9 14 10 10  7  5  3  4 11  7  8  7  7  7  5 10  6 11  9 13  4 11 17 12
#  16  9  6  7  4 15  5  2  5  1 11]

# %%
m = np.empty((3,3), dtype=list)
m[0][0] = [1,2,3]
print(m)
# Out:
# [[list([1, 2, 3]) None None]
#  [None None None]
#  [None None None]]

# %%
def draw_sequence(x,y,w,c):
    p.circle(x, y, size = w, color = c)
    p.line(x, y, line_width = w, color = c)

# %%
#p.image_url(url=['map.png'], x=0, y=20, w=24, h=20)

#source = ColumnDataSource(data=dict(x=[17, 18, 12, 9, 9, 9, 18, 2, 5],
#                                    y=[9, 14, 10, 10, 7, 5, 3, 4, 12],
#                                    names=['Ukraine','Russia', 'Poland', 'Germany', 'Czechia',
#                                           'Italy', 'Turkey', 'Spain', 'United Kingdom']))
#labels = LabelSet(x='x', y='y', text='names', x_offset=5, y_offset=5, source=source, render_mode='canvas')
#p.add_layout(labels)

#draw_sequence(RU_x, RU_y, 2, "red")
#draw_sequence(PL_x, PL_y, 2, "red")
#draw_sequence(DE_x, DE_y, 2, "red")
#draw_sequence(CZ_x, CZ_y, 2, "red")
#draw_sequence(IT_x, IT_y, 2, "red")
#draw_sequence(TR_x, TR_y, 2, "red")
#draw_sequence(ES_x, ES_y, 2, "red")
#draw_sequence(UK_x, UK_y, 2, "red")
#draw_sequence(FR_x, FR_y, 2, "red")
#draw_sequence(RO_x, RO_y, 2, "red")
#draw_sequence(BG_x, BG_y, 2, "red")
#draw_sequence(GR_x, GR_y, 2, "red")
#draw_sequence(BY_x, BY_y, 2, "red")
#draw_sequence(NL_x, NL_y, 2, "red")

# show the figure
#show(p)

# %%
p.image_url(url=['maps/europe.jpeg'], x=0, y=20, w=24, h=20)

draw_sequence(UA_RU_x, UA_RU_y, 2, "red")

draw_sequence(UA_RO_BG_x, UA_RO_BG_y, 2, "red")

draw_sequence(UA_RO_BG_x, UA_RO_BG_y, 2, "red")

draw_sequence(UA_PL_DE_x, UA_PL_DE_y, 2, "red")

draw_sequence(UA_PL_DE_FR_x, UA_PL_DE_FR_y, 2, "red")

draw_sequence(UA_BY_RU_x, UA_BY_RU_y, 2, "red")

draw_sequence(UA_TR_GR_IT_FR_x, UA_TR_GR_IT_FR_y, 2, "red")

# show the figure
show(p)
# Out:
#   <div class="bk-root" id="9e9d9aba-f7d2-4f97-95d6-8e135379f363" data-root-id="1003"></div>
